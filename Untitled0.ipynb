# %% [markdown]
# <a href="https://colab.research.google.com/github/Keira19101/inc0gnida/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import os
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Подключим библиотеки.

# %%
data = pd.read_csv('/content/sample_data/diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.Outcome.value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# %matplotlib inline

# %%
data.hist(bins=50,figsize=(20,20))
plt.show();

# %%
corr_matrix = data.corr()
corr_matrix['Glucose'].sort_values(ascending=False)
# Out:
# Glucose                     1.000000
# Outcome                     0.466581
# Insulin                     0.331357
# Age                         0.263514
# BMI                         0.221071
# BloodPressure               0.152590
# DiabetesPedigreeFunction    0.137337
# Pregnancies                 0.129459
# SkinThickness               0.057328
# Name: Glucose, dtype: float64

# %%
corr_matrix = data.corr()
corr_matrix['BMI'].sort_values(ascending=False)
# Out:
# BMI                         1.000000
# SkinThickness               0.392573
# Outcome                     0.292695
# BloodPressure               0.281805
# Glucose                     0.221071
# Insulin                     0.197859
# DiabetesPedigreeFunction    0.140647
# Age                         0.036242
# Pregnancies                 0.017683
# Name: BMI, dtype: float64

# %%
import seaborn as sns
plt.figure(figsize=(30,30))
sns.heatmap(data.corr(),annot = True, cmap = 'Purples');

# %%
from pandas.plotting import scatter_matrix

attributes = ['Glucose','Insulin','Age','BMI']
scatter_matrix(data[attributes],figsize=(15,10));

# %%
data.plot(kind='scatter',x='Glucose',y = 'BMI',alpha = 0.1,s=data['SkinThickness'],label='Outcome',figsize=(10,7),c='DiabetesPedigreeFunction',cmap = plt.get_cmap('jet'),colorbar=True)
plt.legend()

# %%
data['Pressure_per_Age'] = data['BloodPressure'] / data['Age']
data['Glucose_per_Pressure'] = data['Glucose'] / data['BloodPressure']
data['SkinThickness_per_Age'] = data['SkinThickness'] / data['Age']
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  Pressure_per_Age  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 12 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
#  9   Pressure_per_Age          768 non-null    float64
#  10  Glucose_per_Pressure      768 non-null    float64
#  11  SkinThickness_per_Age     768 non-null    float64
# dtypes: float64(5), int64(7)
# memory usage: 72.1 KB

# %%
corr_matrix = data.corr()
corr_matrix['Glucose'].sort_values(ascending=False)
# Out:
# Glucose                     1.000000
# Glucose_per_Pressure        0.765258
# Outcome                     0.466581
# Insulin                     0.331357
# Age                         0.263514
# BMI                         0.221071
# BloodPressure               0.152590
# DiabetesPedigreeFunction    0.137337
# Pregnancies                 0.129459
# SkinThickness               0.057328
# SkinThickness_per_Age      -0.032510
# Pressure_per_Age           -0.096052
# Name: Glucose, dtype: float64

# %% [markdown]
# Обнаружена корреляция между параметрами Глюкоза и Давление. Подготовлены данные для выбора модели.
